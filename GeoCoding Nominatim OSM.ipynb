# %% [markdown]
# # Introduction
# The Nominatim API is a REST API (provided by OpenStreetMap), that returns geographic coordinates (latitude and longitude) from a postal address. If several postal addresses (due to inaccuracy or non-existent street number) corresponding to the request are found, the API returns several coordinates, each time with an `importance` score. The coordinates are given in descending order of importance, so you can select only the first address.

# %%
# Execute the code below :

import requests

link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json"
#r = requests.get(link)
headers = {
    'User-Agent': 'YourAppName/1.0 (your_email@example.com)'
}
r = requests.get(link, headers=headers).json()

r
# Out:
# [{'place_id': 331448840,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 1203329854,
#   'lat': '37.7242361',
#   'lon': '15.1789984',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Altarello, Giarre, Catania, Sicilia, 95014, Italia',
#   'boundingbox': ['37.7234970', '37.7249937', '15.1784912', '15.1794786']},
#  {'place_id': 78785692,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 58232256,
#   'lat': '37.6091358',
#   'lon': '15.1596388',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Sciarelle, Acireale, Catania, Sicilia, 95024, Italia',
#   'boundingbox': ['37.6088571', '37.6091358', '15.1591549', '15.1602847']},
#  {'place_id': 78896223,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 128394486,
#   'lat': '37.6090903',
#   'lon': '15.1604414',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Santa Caterina, Acireale, Catania, Sicilia, 95024, Italia',
#   'boundingbox': ['37.6089805', '37.6091110', '15.1602847', '15.1610300']},
#  {'place_id': 79114199,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 167016177,
#   'lat': '37.5676811',
#   'lon': '14.9106709',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Paternò, Catania, Sicilia, 95047, Italia',
#   'boundingbox': ['37.5673863', '37.5680619', '14.9106500', '14.9109837']},
#  {'place_id': 78789063,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 340599607,
#   'lat': '37.213333',
#   'lon': '14.6341795',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Grammichele, Catania, Sicilia, 95042, Italia',
#   'boundingbox': ['37.2132636', '37.2135294', '14.6341245', '14.6343514']},
#  {'place_id': 78788845,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 1125079468,
#   'lat': '37.22508',
#   'lon': '14.5244911',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Caltagirone, Catania, Sicilia, 95041, Italia',
#   'boundingbox': ['37.2250444', '37.2253490', '14.5244318', '14.5249395']},
#  {'place_id': 78839183,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 82142425,
#   'lat': '37.3859977',
#   'lon': '14.6916633',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Ramacca, Catania, Sicilia, 95040, Italia',
#   'boundingbox': ['37.3845850', '37.3874239', '14.6912861', '14.6920440']},
#  {'place_id': 78843860,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 223112430,
#   'lat': '37.2970326',
#   'lon': '14.8417094',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Scordia, Catania, Sicilia, 95048, Italia',
#   'boundingbox': ['37.2968575', '37.2971447', '14.8410915', '14.8419764']},
#  {'place_id': 78958671,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 1092232142,
#   'lat': '37.3293593',
#   'lon': '14.7414437',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Palagonia, Catania, Sicilia, 95046, Italia',
#   'boundingbox': ['37.3287325', '37.3297427', '14.7407703', '14.7425445']},
#  {'place_id': 79081035,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 75224730,
#   'lat': '37.4769218',
#   'lon': '14.533668',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Raddusa, Catania, Sicilia, 95040, Italia',
#   'boundingbox': ['37.4763164', '37.4778478', '14.5328669', '14.5348934']}]

# %%
# Here we select only the first address (index 0)
print("First address :", r[0])
print("First address longitude :",r[0]['lon'])
print("First address latitude :",r[0]['lat'])
# Out:
# First address : {'place_id': 45768607, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1203329854, 'lat': '37.7242361', 'lon': '15.1789984', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.10000999999999993, 'addresstype': 'road', 'name': 'Via Pietro Mascagni', 'display_name': 'Via Pietro Mascagni, Altarello, Giarre, Catania, Sicilia, 95014, Italia', 'boundingbox': ['37.7234970', '37.7249937', '15.1784912', '15.1794786']}
# First address longitude : 15.1789984
# First address latitude : 37.7242361

# %%
# For ease of use, you can add a limit on the number of items returned:

link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json"
r = requests.get(link).json()
print("WITHOUT limit, how many coordinates does this address return?",len(r))

link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json&limit=1"
r = requests.get(link).json()
print("WITH limit, how many coordinates does this address return?",len(r))
# Out:
# WITHOUT limit, how many coordinates does this address return? 10
# WITH limit, how many coordinates does this address return? 1

# %% [markdown]
# ## How to create your API query
# It's up to you to modify the string to create the right request URL

# %%
# We observe that the query consists of a fixed part, followed by the address to be searched for.
# An URL cannot contain a " " space character,
# and special characters or accents should be avoided if possible

link_main = 'https://nominatim.openstreetmap.org/?q='
address = '54 Via Pietro Mascagni, Catania, Italy'
link_end = '&format=json&limit=1'

link = link_main + address.replace(' ','+')# It's your turn here. Your goal is to get a link in the right format

print(link + link_end)
# Out:
# https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,+Catania,+Italy&format=json&limit=1

# %%
# Create a function here that turns a postal address into a request URL for the Nominatim API,
# then makes the request and returns the coordinates :

def API_address(postal_address):
  link_main = 'https://nominatim.openstreetmap.org/?q='
  address = '54 Via Pietro Mascagni, Catania, Italy'
  link_end = '&format=json&limit=1'

  link = link_main + address.replace(' ','+')

  return print(link + link_end)

# %%
# Test it here:
API_address(address)
# Out:
# https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,+Catania,+Italy&format=json&limit=1

# %% [markdown]
# # DataViz
# Latitude & Longitude can be used on visualization tools, whether they are BI tools (PowerBI, Table), or Python DataViz libraries such as Plotly or Folium.
#
# Here we will display a map with Folium.

# %%
# The syntax of Folium is very simple, you start by creating a map centered on a point.
# You can change the default zoom level with the argument "zoom_start".

import folium

# We define a location as a list with 2 values : latitude and longitude.
point = [float(r[0]['lat']), float(r[0]['lon'])]

# We center the map on the location
m = folium.Map(location=point,zoom_start=7)

# We display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46357451f998fb66d736f965de43ff94 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46357451f998fb66d736f965de43ff94&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46357451f998fb66d736f965de43ff94 = L.map(
#                 &quot;map_46357451f998fb66d736f965de43ff94&quot;,
#                 {
#                     center: [37.7242361, 15.1789984],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93ac6159ccb0c33d10f936f2192c9cbf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_46357451f998fb66d736f965de43ff94);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Then you can add landmarks and put a clickable comment
m = folium.Map(location=point, )
folium.Marker(
    location=point,
    popup='a good restaurant'
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2329e61f4b0e1f1d67b17b80b555ab89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2329e61f4b0e1f1d67b17b80b555ab89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2329e61f4b0e1f1d67b17b80b555ab89 = L.map(
#                 &quot;map_2329e61f4b0e1f1d67b17b80b555ab89&quot;,
#                 {
#                     center: [37.7242361, 15.1789984],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_33cb783d37ca1411e8a5b197afae0b95 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2329e61f4b0e1f1d67b17b80b555ab89);
#
#
#             var marker_48842a0b5886b61e4f19e8850d65888a = L.marker(
#                 [37.7242361, 15.1789984],
#                 {}
#             ).addTo(map_2329e61f4b0e1f1d67b17b80b555ab89);
#
#
#         var popup_380fc4fcc599902cf407d9a5cb4ef21c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_11bc74ad044fd5780ca327b2c1b1b7fe = $(`&lt;div id=&quot;html_11bc74ad044fd5780ca327b2c1b1b7fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;a good restaurant&lt;/div&gt;`)[0];
#                 popup_380fc4fcc599902cf407d9a5cb4ef21c.setContent(html_11bc74ad044fd5780ca327b2c1b1b7fe);
#
#
#
#         marker_48842a0b5886b61e4f19e8850d65888a.bindPopup(popup_380fc4fcc599902cf407d9a5cb4ef21c)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Challenge
# Here is a DataFrame with restaurants in Catania, Sicily, and their respective addresses. Here is your mission:
# - Create a new column "coordinates", which will store the coordinates corresponding to each address (you can use the function you created previously).
# - Display a map with the 4 restaurant markers. Be careful, the restaurants are very close, remember to set the default zoom level so that it is clearly legible. You can center the map on the first restaurant. And display the name of the restaurant in the tooltip popup.

# %%
import pandas as pd
restaurants = pd.DataFrame([["Gelateria Zio Pietro dal 1964", "Via Porta di Ferro, 47, 95131 Catania CT"],
                            ["A Casa d'Amici","Via Fischetti, 14, 95131 Catania CT"],
                            ["La Bitta", "Via Acquicella Porto, 95121 Catania CT"],
                            ["Steak House", "Via Porta di Ferro, 8, 95100 Catania CT"]
                            ],
                           columns = ["name", "address"])

restaurants
# Out:
#                             name                                   address
# 0  Gelateria Zio Pietro dal 1964  Via Porta di Ferro, 47, 95131 Catania CT
# 1                 A Casa d'Amici       Via Fischetti, 14, 95131 Catania CT
# 2                       La Bitta    Via Acquicella Porto, 95121 Catania CT
# 3                    Steak House   Via Porta di Ferro, 8, 95100 Catania CT

# %%
restaurants['address'].info()
restaurants['coordonnees']=restaurants['address'].convert_dtypes('string')

restaurants['coordonnees'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4 entries, 0 to 3
# Series name: address
# Non-Null Count  Dtype
# --------------  -----
# 4 non-null      object
# dtypes: object(1)
# memory usage: 160.0+ bytes
# <class 'pandas.core.series.Series'>
# RangeIndex: 4 entries, 0 to 3
# Series name: coordonnees
# Non-Null Count  Dtype
# --------------  -----
# 4 non-null      string
# dtypes: string(1)
# memory usage: 160.0 bytes

# %%
restaurants['coordonnees']
# Out:
# 0    Via Porta di Ferro, 47, 95131 Catania CT
# 1         Via Fischetti, 14, 95131 Catania CT
# 2      Via Acquicella Porto, 95121 Catania CT
# 3     Via Porta di Ferro, 8, 95100 Catania CT
# Name: coordonnees, dtype: string

# %%
def API_address(address):

    link_main = 'https://nominatim.openstreetmap.org/?q='
    link_end = '&format=json&limit=1'

    link = link_main + address.replace(' ','+')

    link=(link + link_end)

    import requests

    r = requests.get(link).json()

    point = [float(r[0]['lat']), float(r[0]['lon'])]

    return point

# %%
restaurants['coordonnees']=restaurants['coordonnees'].apply(API_address)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'coordonnees'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-005577a8070b> in <cell line: 1>()
# ----> 1 restaurants['coordonnees']=restaurants['coordonnees'].apply(API_address)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'coordonnees'

# %%
restaurants['coordonnees']
# Out:
# 0    [37.5020931, 15.0931951]
# 1     [37.506171, 15.0943223]
# 2    [37.4889155, 15.0833748]
# 3    [37.5029335, 15.0930406]
# Name: coordonnees, dtype: object

# %%
import folium

m = folium.Map(location=restaurants['coordonnees'][0],zoom_start=7)

# %%
import folium

m = folium.Map(location=restaurants['coordonnees'][0],zoom_start=7)

for index, ligne in restaurants.iterrows():

  folium.Marker(
     location=ligne['coordonnees'],
     popup='resto'
      ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a4213b4769eff4acefa03ecbcfa37b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a4213b4769eff4acefa03ecbcfa37b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a4213b4769eff4acefa03ecbcfa37b7 = L.map(
#                 &quot;map_4a4213b4769eff4acefa03ecbcfa37b7&quot;,
#                 {
#                     center: [37.5020931, 15.0931951],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6d2dee2b2864d4e70b3580cb0b85bb0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4a4213b4769eff4acefa03ecbcfa37b7);
#
#
#             var marker_234b444af09a99dc3f390c0b0302d298 = L.marker(
#                 [37.5020931, 15.0931951],
#                 {}
#             ).addTo(map_4a4213b4769eff4acefa03ecbcfa37b7);
#
#
#         var popup_72636766dc286462a5af5d5ec39f5506 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68fa75ce21bfb6235e94a7e982abf99e = $(`&lt;div id=&quot;html_68fa75ce21bfb6235e94a7e982abf99e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;resto&lt;/div&gt;`)[0];
#                 popup_72636766dc286462a5af5d5ec39f5506.setContent(html_68fa75ce21bfb6235e94a7e982abf99e);
#
#
#
#         marker_234b444af09a99dc3f390c0b0302d298.bindPopup(popup_72636766dc286462a5af5d5ec39f5506)
#         ;
#
#
#
#
#             var marker_c9dcfec13cc755e48c7be188629a0281 = L.marker(
#                 [37.506171, 15.0943223],
#                 {}
#             ).addTo(map_4a4213b4769eff4acefa03ecbcfa37b7);
#
#
#         var popup_819b1d15d0c21090047e82a95da09764 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_51761598acff1c0084c63354ed707da7 = $(`&lt;div id=&quot;html_51761598acff1c0084c63354ed707da7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;resto&lt;/div&gt;`)[0];
#                 popup_819b1d15d0c21090047e82a95da09764.setContent(html_51761598acff1c0084c63354ed707da7);
#
#
#
#         marker_c9dcfec13cc755e48c7be188629a0281.bindPopup(popup_819b1d15d0c21090047e82a95da09764)
#         ;
#
#
#
#
#             var marker_6125a64fea7a73355ac20b2360f9951a = L.marker(
#                 [37.4889155, 15.0833748],
#                 {}
#             ).addTo(map_4a4213b4769eff4acefa03ecbcfa37b7);
#
#
#         var popup_8742900493c70f030c9af3e3f5efd26b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_027cf2994c1ee2901ab7f642f4fb3847 = $(`&lt;div id=&quot;html_027cf2994c1ee2901ab7f642f4fb3847&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;resto&lt;/div&gt;`)[0];
#                 popup_8742900493c70f030c9af3e3f5efd26b.setContent(html_027cf2994c1ee2901ab7f642f4fb3847);
#
#
#
#         marker_6125a64fea7a73355ac20b2360f9951a.bindPopup(popup_8742900493c70f030c9af3e3f5efd26b)
#         ;
#
#
#
#
#             var marker_a1e80ead88507575e4dc5dc684a4bc58 = L.marker(
#                 [37.5029335, 15.0930406],
#                 {}
#             ).addTo(map_4a4213b4769eff4acefa03ecbcfa37b7);
#
#
#         var popup_379011b5986dd87768803295bcbe5da5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bc48de95e0ad89eb272cbf51e6e8124e = $(`&lt;div id=&quot;html_bc48de95e0ad89eb272cbf51e6e8124e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;resto&lt;/div&gt;`)[0];
#                 popup_379011b5986dd87768803295bcbe5da5.setContent(html_bc48de95e0ad89eb272cbf51e6e8124e);
#
#
#
#         marker_a1e80ead88507575e4dc5dc684a4bc58.bindPopup(popup_379011b5986dd87768803295bcbe5da5)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Remarks on the Nominatim API
# As indicated in the quest, there are many resources for geocoding. Most of them are available by registration, and some require a fee.
#
# The Nominatim API is free and without registration. The disadvantage is that it is relatively slow. If you need to use it in the future, remember to store the results so you don't have to run it several times.
#
# For your knowledge, there is also :
# - the **reverse** address API, which allows you to find the nearest postal address using geographic coordinates.
# - the API from a **CSV file** if you have a lot of addresses to geocode
# - the API **GeoJSON** which allows to obtain a geoJSON format of locations to make choropleth maps
#
#
# All the [documentation is available here](https://nominatim.org/release-docs/develop/api/Search/).
